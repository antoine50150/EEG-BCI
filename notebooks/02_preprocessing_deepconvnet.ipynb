# %%
import os
import urllib.request

base_url = "https://physionet.org/files/eegmmidb/1.0.0/"
output_dir = "../data/raw/physionet"
os.makedirs(output_dir, exist_ok=True)

subjects = [f"S{str(i).zfill(3)}" for i in range(1, 11)]  # S001 à S010
runs = [f"R{str(i).zfill(2)}" for i in range(1, 15)]      # R01 à R14

downloaded = 0
for subject in subjects:
    for run in runs:
        filename = f"{subject}{run}.edf"
        url = f"{base_url}{subject}/{filename}"
        local_path = os.path.join(output_dir, filename)

        if os.path.exists(local_path):
            continue  # déjà présent

        try:
            print(f"Téléchargement de {filename}...")
            urllib.request.urlretrieve(url, local_path)
            downloaded += 1
        except Exception as e:
            print(f"❌ Échec : {filename} ({e})")

print(f"\n✅ Téléchargements terminés : {downloaded} fichiers")
# Out:
# ✅ Téléchargements terminés : 0 fichiers

# %%
import os
import glob
import mne
import numpy as np

# 📁 Chemin absolu vers le dossier contenant les fichiers EDF
data_dir = r"C:/Users/Antoi/Documents/EEG-BCI/data/raw/physionet"

# 🔍 Recherche de tous les fichiers EDF dans le dossier
edf_files = sorted(glob.glob(os.path.join(data_dir, "*.edf")))
if len(edf_files) == 0:
    raise FileNotFoundError(f"Aucun fichier EDF trouvé dans {data_dir}")

X_all = []
y_all = []

for file in edf_files:
    print(f"\n📄 Traitement du fichier : {os.path.basename(file)}")

    try:
        # 📥 Chargement des données EEG
        raw = mne.io.read_raw_edf(file, preload=True)
        raw.set_eeg_reference('average', projection=True)

        # 🧠 Appliquer un montage standard
        montage = mne.channels.make_standard_montage("standard_1020")
        raw.set_montage(montage, on_missing="ignore")

        # ❌ Supprimer les canaux problématiques pour la topomap
        bad_chs = ['FCZ', 'CZ', 'CPZ', 'FP1', 'FPZ', 'FP2',
                   'AFZ', 'FZ', 'PZ', 'POZ', 'OZ', 'IZ']
        raw.pick_channels([ch for ch in raw.ch_names if ch not in bad_chs])

        # 🎚️ Filtrage passe-bande 1–40 Hz
        raw.filter(1., 40., fir_design='firwin')

        # 🏷️ Extraction des événements via annotations
        events, _ = mne.events_from_annotations(raw)
        event_id = dict(rest=1, left=2, right=3)

        # 📦 Extraction des epochs
        epochs = mne.Epochs(raw, events, event_id=event_id,
                            tmin=0, tmax=2, baseline=None,
                            preload=True, detrend=1)
        
        # ❗ Skip si aucune epoch détectée
        if len(epochs) == 0:
            print(f"⚠️ Aucune epoch valide dans {file}, ignoré.")
            continue

        # 🔢 Récupération des données [N, C, T]
        data = epochs.get_data()
        labels = epochs.events[:, 2]

        # ⚙️ Normalisation (z-score par trial)
        data = (data - data.mean(axis=-1, keepdims=True)) / data.std(axis=-1, keepdims=True)

        # 🧩 Ajout aux données globales
        X_all.append(data)
        y_all.append(labels)

    except Exception as e:
        print(f"❌ Erreur sur {file} : {e}")

# 🔄 Concaténation finale
X = np.concatenate(X_all, axis=0)
y = np.concatenate(y_all, axis=0)

# 💾 Sauvegarde des arrays
np.save("X_windows.npy", X)
np.save("y_windows.npy", y)

print(f"\n✅ Données prêtes pour DeepConvNet : X = {X.shape}, y = {y.shape}")
# Out:
# 📄 Traitement du fichier : S001R01.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S001R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0')]
# ❌ Erreur sur C:/Users/Antoi/Documents/EEG-BCI/data/raw/physionet\S001R01.edf : No matching events found for left (event id 2)
#
# 📄 Traitement du fichier : S001R02.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S001R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0')]
# ❌ Erreur sur C:/Users/Antoi/Documents/EEG-BCI/data/raw/physionet\S001R02.edf : No matching events found for left (event id 2)
#
# 📄 Traitement du fichier : S001R03.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S001R03.edf...
# EDF file detected
# Setting channel info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S001R04.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S001R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S001R05.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S001R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# EEG channel type selected for re-referencing
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S001R06.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S001R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# EEG channel type selected for re-referencing
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S001R07.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S001R07.edf...
# EDF file detected
# Setting channel info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S001R08.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S001R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S001R09.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S001R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S001R10.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S001R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# EEG channel type selected for re-referencing
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S001R11.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S001R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# EEG channel type selected for re-referencing
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S001R12.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S001R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# EEG channel type selected for re-referencing
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S001R13.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S001R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# EEG channel type selected for re-referencing
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S001R14.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S001R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# EEG channel type selected for re-referencing
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S002R01.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S002R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0')]
# ❌ Erreur sur C:/Users/Antoi/Documents/EEG-BCI/data/raw/physionet\S002R01.edf : No matching events found for left (event id 2)
#
# 📄 Traitement du fichier : S002R02.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S002R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0')]
# ❌ Erreur sur C:/Users/Antoi/Documents/EEG-BCI/data/raw/physionet\S002R02.edf : No matching events found for left (event id 2)
#
# 📄 Traitement du fichier : S002R03.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S002R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S002R04.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S002R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S002R05.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S002R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S002R06.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S002R06.edf...
# EDF file detected
# Setting channel info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S002R07.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S002R07.edf...
# EDF file detected
# Setting channel info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S002R08.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S002R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S002R09.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S002R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S002R10.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S002R10.edf...
# EDF file detected
# Setting channel info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S002R11.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S002R11.edf...
# EDF file detected
# Setting channel info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S002R12.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S002R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S002R13.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S002R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S002R14.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S002R14.edf...
# EDF file detected
# Setting channel info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S003R01.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S003R01.edf...
# EDF file detected
# Setting channel info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0')]
# ❌ Erreur sur C:/Users/Antoi/Documents/EEG-BCI/data/raw/physionet\S003R01.edf : No matching events found for left (event id 2)
#
# 📄 Traitement du fichier : S003R02.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S003R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0')]
# ❌ Erreur sur C:/Users/Antoi/Documents/EEG-BCI/data/raw/physionet\S003R02.edf : No matching events found for left (event id 2)
#
# 📄 Traitement du fichier : S003R03.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S003R03.edf...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# ...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S010R06.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S010R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S010R07.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S010R07.edf...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S010R08.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S010R08.edf...
# EDF file detected
# Setting channel info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S010R09.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S010R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S010R10.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S010R10.edf...
# EDF file detected
# Setting channel info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S010R11.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S010R11.edf...
# EDF file detected
# Setting channel info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S010R12.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S010R12.edf...
# EDF file detected
# Setting channel info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S010R13.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S010R13.edf...
# EDF file detected
# Setting channel info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
#
# 📄 Traitement du fichier : S010R14.edf
# Extracting EDF parameters from C:\Users\Antoi\Documents\EEG-BCI\data\raw\physionet\S010R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 529 samples (3.306 s)
#
# Used Annotations descriptions: [np.str_('T0'), np.str_('T1'), np.str_('T2')]
# Not setting metadata
# 30 matching events found
# No baseline correction applied
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# Using data from preloaded Raw for 30 events and 321 original time points ...
# 0 bad epochs dropped
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.0s finished
# ✅ Données prêtes pour DeepConvNet : X = (3600, 64, 321), y = (3600,)

# %%
from collections import Counter
print(Counter(y))
# Out:
# Counter({np.int64(1): 1800, np.int64(2): 903, np.int64(3): 897})
