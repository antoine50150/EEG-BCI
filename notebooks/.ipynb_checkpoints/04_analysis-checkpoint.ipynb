# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader, ConcatDataset, Subset
import numpy as np
import os, sys
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import StratifiedKFold

# Ajouter le dossier racine au path pour accéder à src/
sys.path.append(os.path.abspath(".."))
from src.models.eegnet import EEGNetLight

def train_multirun():
    subject = 1
    runs = [6, 10, 14]
    data_dir = "../../data/processed"

    # Charger et concaténer les données de plusieurs runs
    datasets = []
    for run in runs:
        path = os.path.join(data_dir, f"subject_{subject}_run_{run}_epochs.npz")
        data = np.load(path)
        X = data["X"]
        y = data["y"]
        # 🧠 Fusion des classes 1 et 2
        y = np.where(y == 2, 1, y)  # 2 → 1
        y = y - y.min()  # Correction pour que ça commence à 0
        X_tensor = torch.tensor(X, dtype=torch.float32).unsqueeze(1)
        y_tensor = torch.tensor(y, dtype=torch.long)
        datasets.append(TensorDataset(X_tensor, y_tensor))

    full_X = torch.cat([d.tensors[0] for d in datasets])
    full_y = torch.cat([d.tensors[1] for d in datasets])

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    fold = 1
    for train_idx, test_idx in skf.split(full_X, full_y):
        print(f"\n===== Fold {fold} =====")
        y_train, y_test = full_y[train_idx], full_y[test_idx]
        print(f"🔢 Répartition y_train : {torch.bincount(y_train)}")
        print(f"🔢 Répartition y_test  : {torch.bincount(y_test)}")

        train_loader = DataLoader(Subset(TensorDataset(full_X, full_y), train_idx), batch_size=8, shuffle=True)
        test_loader = DataLoader(Subset(TensorDataset(full_X, full_y), test_idx), batch_size=8)

        n_channels, n_timepoints = full_X.shape[2], full_X.shape[3]
        n_classes = len(torch.unique(full_y))
        model = EEGNetLight(n_channels=n_channels, n_timepoints=n_timepoints, n_classes=n_classes)
        optimizer = optim.Adam(model.parameters(), lr=1e-3)

        # 🎯 Ajout d'une loss pondérée pour compenser les déséquilibres
        class_counts = torch.bincount(y_train)
        class_weights = 1.0 / class_counts.float()
        class_weights = class_weights / class_weights.sum() * len(class_counts)
        criterion = nn.CrossEntropyLoss(weight=class_weights)

        losses, accuracies = [], []

        for epoch in range(10):
            model.train()
            total_loss, correct, total = 0, 0, 0
            for xb, yb in train_loader:
                optimizer.zero_grad()
                preds = model(xb)
                loss = criterion(preds, yb)
                loss.backward()
                optimizer.step()
                total_loss += loss.item()
                correct += (preds.argmax(1) == yb).sum().item()
                total += yb.size(0)
            acc = 100 * correct / total
            losses.append(total_loss)
            accuracies.append(acc)
            print(f"🧠 Fold {fold} — Epoch {epoch+1:02d} — Loss: {total_loss:.4f} — Acc: {acc:.2f}%")

        # Évaluation
        model.eval()
        y_true, y_pred = [], []
        with torch.no_grad():
            for xb, yb in test_loader:
                preds = model(xb)
                y_true.extend(yb.numpy())
                y_pred.extend(preds.argmax(1).numpy())

        # Matrice de confusion et rapport
        cm = confusion_matrix(y_true, y_pred)
        ConfusionMatrixDisplay(cm).plot()
        plt.title(f"Matrice de confusion - Fold {fold}")
        plt.grid(False)
        plt.show()

        print("\n🔎 Rapport de classification :")
        print(classification_report(y_true, y_pred, zero_division=0))

        # Exporter stats
        np.savez(f"../../models/eegnet_subject{subject}_fold{fold}_stats.npz",
                 losses=np.array(losses), accuracies=np.array(accuracies))
        print(f"📦 Courbes sauvegardées dans eegnet_subject{subject}_fold{fold}_stats.npz")

        fold += 1

if __name__ == "__main__":
    train_multirun()
# Out:
# ===== Fold 1 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 1 — Epoch 01 — Loss: 6.2300 — Acc: 55.56%
# 🧠 Fold 1 — Epoch 02 — Loss: 6.1061 — Acc: 86.11%
# 🧠 Fold 1 — Epoch 03 — Loss: 5.8127 — Acc: 87.50%
# 🧠 Fold 1 — Epoch 04 — Loss: 5.1082 — Acc: 83.33%
# 🧠 Fold 1 — Epoch 05 — Loss: 4.1961 — Acc: 81.94%
# 🧠 Fold 1 — Epoch 06 — Loss: 3.2772 — Acc: 83.33%
# 🧠 Fold 1 — Epoch 07 — Loss: 2.5774 — Acc: 84.72%
# 🧠 Fold 1 — Epoch 08 — Loss: 1.9529 — Acc: 88.89%
# 🧠 Fold 1 — Epoch 09 — Loss: 1.5107 — Acc: 91.67%
# 🧠 Fold 1 — Epoch 10 — Loss: 1.2578 — Acc: 95.83%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         9
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold1_stats.npz
#
# ===== Fold 2 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 2 — Epoch 01 — Loss: 6.2363 — Acc: 51.39%
# 🧠 Fold 2 — Epoch 02 — Loss: 6.0213 — Acc: 75.00%
# 🧠 Fold 2 — Epoch 03 — Loss: 5.5851 — Acc: 88.89%
# 🧠 Fold 2 — Epoch 04 — Loss: 4.7288 — Acc: 87.50%
# 🧠 Fold 2 — Epoch 05 — Loss: 3.7990 — Acc: 87.50%
# 🧠 Fold 2 — Epoch 06 — Loss: 3.3273 — Acc: 86.11%
# 🧠 Fold 2 — Epoch 07 — Loss: 2.7749 — Acc: 88.89%
# 🧠 Fold 2 — Epoch 08 — Loss: 2.2783 — Acc: 93.06%
# 🧠 Fold 2 — Epoch 09 — Loss: 2.1943 — Acc: 91.67%
# 🧠 Fold 2 — Epoch 10 — Loss: 1.7419 — Acc: 97.22%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         9
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold2_stats.npz
#
# ===== Fold 3 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 3 — Epoch 01 — Loss: 6.2021 — Acc: 65.28%
# 🧠 Fold 3 — Epoch 02 — Loss: 5.9746 — Acc: 83.33%
# 🧠 Fold 3 — Epoch 03 — Loss: 5.4733 — Acc: 81.94%
# 🧠 Fold 3 — Epoch 04 — Loss: 4.7181 — Acc: 84.72%
# 🧠 Fold 3 — Epoch 05 — Loss: 3.7909 — Acc: 83.33%
# 🧠 Fold 3 — Epoch 06 — Loss: 3.2521 — Acc: 83.33%
# 🧠 Fold 3 — Epoch 07 — Loss: 2.9282 — Acc: 84.72%
# 🧠 Fold 3 — Epoch 08 — Loss: 2.4255 — Acc: 91.67%
# 🧠 Fold 3 — Epoch 09 — Loss: 2.2414 — Acc: 93.06%
# 🧠 Fold 3 — Epoch 10 — Loss: 1.8111 — Acc: 95.83%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         9
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold3_stats.npz
#
# ===== Fold 4 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 4 — Epoch 01 — Loss: 6.2269 — Acc: 56.94%
# 🧠 Fold 4 — Epoch 02 — Loss: 6.1003 — Acc: 83.33%
# 🧠 Fold 4 — Epoch 03 — Loss: 5.7746 — Acc: 84.72%
# 🧠 Fold 4 — Epoch 04 — Loss: 5.1006 — Acc: 81.94%
# 🧠 Fold 4 — Epoch 05 — Loss: 4.1336 — Acc: 81.94%
# 🧠 Fold 4 — Epoch 06 — Loss: 3.3337 — Acc: 83.33%
# 🧠 Fold 4 — Epoch 07 — Loss: 2.7279 — Acc: 86.11%
# 🧠 Fold 4 — Epoch 08 — Loss: 2.2780 — Acc: 93.06%
# 🧠 Fold 4 — Epoch 09 — Loss: 1.8957 — Acc: 93.06%
# 🧠 Fold 4 — Epoch 10 — Loss: 1.4383 — Acc: 97.22%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         9
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold4_stats.npz
#
# ===== Fold 5 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 5 — Epoch 01 — Loss: 6.2248 — Acc: 59.72%
# 🧠 Fold 5 — Epoch 02 — Loss: 6.0383 — Acc: 80.56%
# 🧠 Fold 5 — Epoch 03 — Loss: 5.5359 — Acc: 83.33%
# 🧠 Fold 5 — Epoch 04 — Loss: 4.5914 — Acc: 84.72%
# 🧠 Fold 5 — Epoch 05 — Loss: 3.7271 — Acc: 84.72%
# 🧠 Fold 5 — Epoch 06 — Loss: 3.0848 — Acc: 86.11%
# 🧠 Fold 5 — Epoch 07 — Loss: 2.8984 — Acc: 87.50%
# 🧠 Fold 5 — Epoch 08 — Loss: 2.4643 — Acc: 93.06%
# 🧠 Fold 5 — Epoch 09 — Loss: 2.4405 — Acc: 90.28%
# 🧠 Fold 5 — Epoch 10 — Loss: 2.0431 — Acc: 91.67%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         9
#            1       0.50      1.00      0.67         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold5_stats.npz

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader, ConcatDataset, Subset
import numpy as np
import os, sys
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import StratifiedKFold

# Ajouter le dossier racine au path pour accéder à src/
sys.path.append(os.path.abspath(".."))
from src.models.eegnet import EEGNetLight

def train_multirun():
    subject = 1
    runs = [6, 10, 14]
    data_dir = "../../data/processed"

    # Charger et concaténer les données de plusieurs runs
    datasets = []
    for run in runs:
        path = os.path.join(data_dir, f"subject_{subject}_run_{run}_epochs.npz")
        data = np.load(path)
        X = data["X"]
        y = data["y"]
        # 🧠 Fusion des classes 1 et 2
        y = np.where(y == 2, 1, y)  # 2 → 1
        y = y - y.min()  # Correction pour que ça commence à 0
        X_tensor = torch.tensor(X, dtype=torch.float32).unsqueeze(1)
        y_tensor = torch.tensor(y, dtype=torch.long)
        datasets.append(TensorDataset(X_tensor, y_tensor))

    full_X = torch.cat([d.tensors[0] for d in datasets])
    full_y = torch.cat([d.tensors[1] for d in datasets])

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    fold = 1
    for train_idx, test_idx in skf.split(full_X, full_y):
        print(f"\n===== Fold {fold} =====")
        y_train, y_test = full_y[train_idx], full_y[test_idx]
        print(f"🔢 Répartition y_train : {torch.bincount(y_train)}")
        print(f"🔢 Répartition y_test  : {torch.bincount(y_test)}")

        train_loader = DataLoader(Subset(TensorDataset(full_X, full_y), train_idx), batch_size=8, shuffle=True)
        test_loader = DataLoader(Subset(TensorDataset(full_X, full_y), test_idx), batch_size=8)

        n_channels, n_timepoints = full_X.shape[2], full_X.shape[3]
        n_classes = len(torch.unique(full_y))
        model = EEGNetLight(n_channels=n_channels, n_timepoints=n_timepoints, n_classes=n_classes)
        optimizer = optim.Adam(model.parameters(), lr=1e-3)

        # 🔧 Pondération des classes dans la loss
        class_counts = torch.bincount(y_train)
        class_weights = 1. / class_counts.float()
        weights = class_weights / class_weights.sum()
        criterion = nn.CrossEntropyLoss(weight=weights)

        losses, accuracies = [], []

        for epoch in range(10):
            model.train()
            total_loss, correct, total = 0, 0, 0
            for xb, yb in train_loader:
                optimizer.zero_grad()
                preds = model(xb)
                loss = criterion(preds, yb)
                loss.backward()
                optimizer.step()
                total_loss += loss.item()
                correct += (preds.argmax(1) == yb).sum().item()
                total += yb.size(0)
            acc = 100 * correct / total
            losses.append(total_loss)
            accuracies.append(acc)
            print(f"🧠 Fold {fold} — Epoch {epoch+1:02d} — Loss: {total_loss:.4f} — Acc: {acc:.2f}%")

        # Évaluation
        model.eval()
        y_true, y_pred = [], []
        with torch.no_grad():
            for xb, yb in test_loader:
                preds = model(xb)
                y_true.extend(yb.numpy())
                y_pred.extend(preds.argmax(1).numpy())

        cm = confusion_matrix(y_true, y_pred)
        ConfusionMatrixDisplay(cm).plot()
        plt.title(f"Matrice de confusion - Fold {fold}")
        plt.grid(False)
        plt.show()

        print("\n🔎 Rapport de classification :")
        print(classification_report(y_true, y_pred, zero_division=0))

        # Exporter stats
        np.savez(f"../../models/eegnet_subject{subject}_fold{fold}_stats.npz",
                 losses=np.array(losses), accuracies=np.array(accuracies))
        print(f"📦 Courbes sauvegardées dans eegnet_subject{subject}_fold{fold}_stats.npz")

        fold += 1

if __name__ == "__main__":
    train_multirun()
# Out:
# ===== Fold 1 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 1 — Epoch 01 — Loss: 6.2229 — Acc: 63.89%
# 🧠 Fold 1 — Epoch 02 — Loss: 6.0200 — Acc: 84.72%
# 🧠 Fold 1 — Epoch 03 — Loss: 5.6167 — Acc: 84.72%
# 🧠 Fold 1 — Epoch 04 — Loss: 4.7683 — Acc: 84.72%
# 🧠 Fold 1 — Epoch 05 — Loss: 3.8702 — Acc: 86.11%
# 🧠 Fold 1 — Epoch 06 — Loss: 3.0615 — Acc: 87.50%
# 🧠 Fold 1 — Epoch 07 — Loss: 2.4600 — Acc: 88.89%
# 🧠 Fold 1 — Epoch 08 — Loss: 1.9812 — Acc: 91.67%
# 🧠 Fold 1 — Epoch 09 — Loss: 1.5040 — Acc: 95.83%
# 🧠 Fold 1 — Epoch 10 — Loss: 1.1804 — Acc: 98.61%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         9
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold1_stats.npz
#
# ===== Fold 2 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 2 — Epoch 01 — Loss: 6.2248 — Acc: 50.00%
# 🧠 Fold 2 — Epoch 02 — Loss: 6.0287 — Acc: 72.22%
# 🧠 Fold 2 — Epoch 03 — Loss: 5.6100 — Acc: 75.00%
# 🧠 Fold 2 — Epoch 04 — Loss: 4.8600 — Acc: 79.17%
# 🧠 Fold 2 — Epoch 05 — Loss: 4.0258 — Acc: 83.33%
# 🧠 Fold 2 — Epoch 06 — Loss: 3.4529 — Acc: 87.50%
# 🧠 Fold 2 — Epoch 07 — Loss: 2.9364 — Acc: 87.50%
# 🧠 Fold 2 — Epoch 08 — Loss: 2.5832 — Acc: 90.28%
# 🧠 Fold 2 — Epoch 09 — Loss: 2.1213 — Acc: 94.44%
# 🧠 Fold 2 — Epoch 10 — Loss: 1.8665 — Acc: 95.83%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         9
#            1       0.50      1.00      0.67         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold2_stats.npz
#
# ===== Fold 3 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 3 — Epoch 01 — Loss: 6.2185 — Acc: 55.56%
# 🧠 Fold 3 — Epoch 02 — Loss: 6.0344 — Acc: 83.33%
# 🧠 Fold 3 — Epoch 03 — Loss: 5.6220 — Acc: 79.17%
# 🧠 Fold 3 — Epoch 04 — Loss: 4.8628 — Acc: 76.39%
# 🧠 Fold 3 — Epoch 05 — Loss: 4.1782 — Acc: 79.17%
# 🧠 Fold 3 — Epoch 06 — Loss: 3.5371 — Acc: 79.17%
# 🧠 Fold 3 — Epoch 07 — Loss: 3.0729 — Acc: 81.94%
# 🧠 Fold 3 — Epoch 08 — Loss: 2.5939 — Acc: 90.28%
# 🧠 Fold 3 — Epoch 09 — Loss: 2.0338 — Acc: 94.44%
# 🧠 Fold 3 — Epoch 10 — Loss: 1.7472 — Acc: 97.22%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         9
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold3_stats.npz
#
# ===== Fold 4 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 4 — Epoch 01 — Loss: 6.2197 — Acc: 52.78%
# 🧠 Fold 4 — Epoch 02 — Loss: 5.9974 — Acc: 83.33%
# 🧠 Fold 4 — Epoch 03 — Loss: 5.4937 — Acc: 83.33%
# 🧠 Fold 4 — Epoch 04 — Loss: 4.6851 — Acc: 80.56%
# 🧠 Fold 4 — Epoch 05 — Loss: 3.9151 — Acc: 80.56%
# 🧠 Fold 4 — Epoch 06 — Loss: 3.2754 — Acc: 81.94%
# 🧠 Fold 4 — Epoch 07 — Loss: 2.8237 — Acc: 91.67%
# 🧠 Fold 4 — Epoch 08 — Loss: 2.3820 — Acc: 91.67%
# 🧠 Fold 4 — Epoch 09 — Loss: 2.0994 — Acc: 93.06%
# 🧠 Fold 4 — Epoch 10 — Loss: 1.7538 — Acc: 95.83%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         9
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold4_stats.npz
#
# ===== Fold 5 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 5 — Epoch 01 — Loss: 6.2246 — Acc: 50.00%
# 🧠 Fold 5 — Epoch 02 — Loss: 6.0484 — Acc: 81.94%
# 🧠 Fold 5 — Epoch 03 — Loss: 5.6341 — Acc: 84.72%
# 🧠 Fold 5 — Epoch 04 — Loss: 4.8870 — Acc: 81.94%
# 🧠 Fold 5 — Epoch 05 — Loss: 4.0493 — Acc: 83.33%
# 🧠 Fold 5 — Epoch 06 — Loss: 3.5721 — Acc: 84.72%
# 🧠 Fold 5 — Epoch 07 — Loss: 2.9832 — Acc: 88.89%
# 🧠 Fold 5 — Epoch 08 — Loss: 2.4983 — Acc: 90.28%
# 🧠 Fold 5 — Epoch 09 — Loss: 2.2852 — Acc: 88.89%
# 🧠 Fold 5 — Epoch 10 — Loss: 1.9694 — Acc: 93.06%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       1.00      0.11      0.20         9
#            1       0.53      1.00      0.69         9
#
#     accuracy                           0.56        18
#    macro avg       0.76      0.56      0.45        18
# weighted avg       0.76      0.56      0.45        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold5_stats.npz

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader, ConcatDataset, Subset
import numpy as np
import os, sys
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler

# Ajouter le dossier racine au path pour accéder à src/
sys.path.append(os.path.abspath(".."))
from src.models.eegnet import EEGNetLight

def train_multirun():
    subject = 1
    runs = [6, 10, 14]
    data_dir = "../../data/processed"

    # Charger et concaténer les données de plusieurs runs
    datasets = []
    for run in runs:
        path = os.path.join(data_dir, f"subject_{subject}_run_{run}_epochs.npz")
        data = np.load(path)
        X = data["X"]
        y = data["y"]
        # 🧠 Fusion des classes 1 et 2
        y = np.where(y == 2, 1, y)  # 2 → 1
        y = y - y.min()  # Correction pour que ça commence à 0
        X_tensor = torch.tensor(X, dtype=torch.float32).unsqueeze(1)
        y_tensor = torch.tensor(y, dtype=torch.long)
        datasets.append(TensorDataset(X_tensor, y_tensor))

    full_X = torch.cat([d.tensors[0] for d in datasets])
    full_y = torch.cat([d.tensors[1] for d in datasets])

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    fold = 1
    for train_idx, test_idx in skf.split(full_X, full_y):
        print(f"\n===== Fold {fold} =====")
        y_train, y_test = full_y[train_idx], full_y[test_idx]
        print(f"🔢 Répartition y_train : {torch.bincount(y_train)}")
        print(f"🔢 Répartition y_test  : {torch.bincount(y_test)}")

        X_train_np = full_X[train_idx].numpy().reshape(len(train_idx), -1)
        y_train_np = y_train.numpy()

        # 🟡 Rééquilibrage avec RandomOverSampler
        ros = RandomOverSampler(random_state=42)
        X_resampled, y_resampled = ros.fit_resample(X_train_np, y_train_np)

        X_train = torch.tensor(X_resampled.reshape(-1, 1, full_X.shape[2], full_X.shape[3]), dtype=torch.float32)
        y_train = torch.tensor(y_resampled, dtype=torch.long)
        X_test = full_X[test_idx]
        y_test = full_y[test_idx]

        train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=8, shuffle=True)
        test_loader = DataLoader(TensorDataset(X_test, y_test), batch_size=8)

        n_channels, n_timepoints = full_X.shape[2], full_X.shape[3]
        n_classes = len(torch.unique(full_y))
        model = EEGNetLight(n_channels=n_channels, n_timepoints=n_timepoints, n_classes=n_classes)
        optimizer = optim.Adam(model.parameters(), lr=1e-3)

        # 🔧 Ajout de poids pour compenser le déséquilibre initial
        class_counts = torch.bincount(y_train)
        weights = 1.0 / class_counts.float()
        class_weights = weights / weights.sum()
        criterion = nn.CrossEntropyLoss(weight=class_weights)

        losses, accuracies = [], []

        for epoch in range(10):
            model.train()
            total_loss, correct, total = 0, 0, 0
            for xb, yb in train_loader:
                optimizer.zero_grad()
                preds = model(xb)
                loss = criterion(preds, yb)
                loss.backward()
                optimizer.step()
                total_loss += loss.item()
                correct += (preds.argmax(1) == yb).sum().item()
                total += yb.size(0)
            acc = 100 * correct / total
            losses.append(total_loss)
            accuracies.append(acc)
            print(f"🧠 Fold {fold} — Epoch {epoch+1:02d} — Loss: {total_loss:.4f} — Acc: {acc:.2f}%")

        # Évaluation
        model.eval()
        y_true, y_pred = [], []
        with torch.no_grad():
            for xb, yb in test_loader:
                preds = model(xb)
                y_true.extend(yb.numpy())
                y_pred.extend(preds.argmax(1).numpy())

        # Matrice de confusion et rapport
        cm = confusion_matrix(y_true, y_pred)
        ConfusionMatrixDisplay(cm).plot()
        plt.title(f"Matrice de confusion - Fold {fold}")
        plt.grid(False)
        plt.show()

        print("\n🔎 Rapport de classification :")
        print(classification_report(y_true, y_pred, zero_division=0))

        # Exporter stats
        np.savez(f"../../models/eegnet_subject{subject}_fold{fold}_stats.npz",
                 losses=np.array(losses), accuracies=np.array(accuracies))
        print(f"📦 Courbes sauvegardées dans eegnet_subject{subject}_fold{fold}_stats.npz")

        fold += 1

if __name__ == "__main__":
    train_multirun()
# Out:
# ===== Fold 1 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 1 — Epoch 01 — Loss: 6.2272 — Acc: 55.56%
# 🧠 Fold 1 — Epoch 02 — Loss: 6.0426 — Acc: 91.67%
# 🧠 Fold 1 — Epoch 03 — Loss: 5.6145 — Acc: 87.50%
# 🧠 Fold 1 — Epoch 04 — Loss: 4.7582 — Acc: 87.50%
# 🧠 Fold 1 — Epoch 05 — Loss: 3.6901 — Acc: 87.50%
# 🧠 Fold 1 — Epoch 06 — Loss: 2.8782 — Acc: 87.50%
# 🧠 Fold 1 — Epoch 07 — Loss: 2.3093 — Acc: 90.28%
# 🧠 Fold 1 — Epoch 08 — Loss: 1.8074 — Acc: 91.67%
# 🧠 Fold 1 — Epoch 09 — Loss: 1.4122 — Acc: 94.44%
# 🧠 Fold 1 — Epoch 10 — Loss: 1.0573 — Acc: 98.61%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         9
#            1       0.50      1.00      0.67         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold1_stats.npz
#
# ===== Fold 2 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 2 — Epoch 01 — Loss: 6.2346 — Acc: 63.89%
# 🧠 Fold 2 — Epoch 02 — Loss: 6.0619 — Acc: 75.00%
# 🧠 Fold 2 — Epoch 03 — Loss: 5.6702 — Acc: 81.94%
# 🧠 Fold 2 — Epoch 04 — Loss: 5.0276 — Acc: 80.56%
# 🧠 Fold 2 — Epoch 05 — Loss: 4.1219 — Acc: 80.56%
# 🧠 Fold 2 — Epoch 06 — Loss: 3.4380 — Acc: 86.11%
# 🧠 Fold 2 — Epoch 07 — Loss: 2.9207 — Acc: 88.89%
# 🧠 Fold 2 — Epoch 08 — Loss: 2.6003 — Acc: 88.89%
# 🧠 Fold 2 — Epoch 09 — Loss: 2.2490 — Acc: 93.06%
# 🧠 Fold 2 — Epoch 10 — Loss: 2.0295 — Acc: 97.22%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       1.00      0.11      0.20         9
#            1       0.53      1.00      0.69         9
#
#     accuracy                           0.56        18
#    macro avg       0.76      0.56      0.45        18
# weighted avg       0.76      0.56      0.45        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold2_stats.npz
#
# ===== Fold 3 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 3 — Epoch 01 — Loss: 6.2194 — Acc: 55.56%
# 🧠 Fold 3 — Epoch 02 — Loss: 5.9773 — Acc: 84.72%
# 🧠 Fold 3 — Epoch 03 — Loss: 5.4891 — Acc: 84.72%
# 🧠 Fold 3 — Epoch 04 — Loss: 4.7181 — Acc: 81.94%
# 🧠 Fold 3 — Epoch 05 — Loss: 4.0993 — Acc: 81.94%
# 🧠 Fold 3 — Epoch 06 — Loss: 3.5580 — Acc: 81.94%
# 🧠 Fold 3 — Epoch 07 — Loss: 3.1785 — Acc: 83.33%
# 🧠 Fold 3 — Epoch 08 — Loss: 2.9122 — Acc: 88.89%
# 🧠 Fold 3 — Epoch 09 — Loss: 2.4785 — Acc: 91.67%
# 🧠 Fold 3 — Epoch 10 — Loss: 2.2378 — Acc: 94.44%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.75      0.67      0.71         9
#            1       0.70      0.78      0.74         9
#
#     accuracy                           0.72        18
#    macro avg       0.72      0.72      0.72        18
# weighted avg       0.73      0.72      0.72        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold3_stats.npz
#
# ===== Fold 4 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 4 — Epoch 01 — Loss: 6.2279 — Acc: 51.39%
# 🧠 Fold 4 — Epoch 02 — Loss: 6.1237 — Acc: 72.22%
# 🧠 Fold 4 — Epoch 03 — Loss: 5.8375 — Acc: 80.56%
# 🧠 Fold 4 — Epoch 04 — Loss: 5.2239 — Acc: 87.50%
# 🧠 Fold 4 — Epoch 05 — Loss: 4.2691 — Acc: 83.33%
# 🧠 Fold 4 — Epoch 06 — Loss: 3.4174 — Acc: 87.50%
# 🧠 Fold 4 — Epoch 07 — Loss: 2.6219 — Acc: 90.28%
# 🧠 Fold 4 — Epoch 08 — Loss: 2.2089 — Acc: 91.67%
# 🧠 Fold 4 — Epoch 09 — Loss: 1.7183 — Acc: 95.83%
# 🧠 Fold 4 — Epoch 10 — Loss: 1.1539 — Acc: 97.22%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         9
#            1       0.50      1.00      0.67         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold4_stats.npz
#
# ===== Fold 5 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 5 — Epoch 01 — Loss: 6.2201 — Acc: 59.72%
# 🧠 Fold 5 — Epoch 02 — Loss: 5.9935 — Acc: 84.72%
# 🧠 Fold 5 — Epoch 03 — Loss: 5.4253 — Acc: 84.72%
# 🧠 Fold 5 — Epoch 04 — Loss: 4.5604 — Acc: 86.11%
# 🧠 Fold 5 — Epoch 05 — Loss: 3.7730 — Acc: 87.50%
# 🧠 Fold 5 — Epoch 06 — Loss: 3.1392 — Acc: 87.50%
# 🧠 Fold 5 — Epoch 07 — Loss: 2.8877 — Acc: 88.89%
# 🧠 Fold 5 — Epoch 08 — Loss: 2.3886 — Acc: 90.28%
# 🧠 Fold 5 — Epoch 09 — Loss: 2.0114 — Acc: 90.28%
# 🧠 Fold 5 — Epoch 10 — Loss: 1.9100 — Acc: 90.28%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         9
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold5_stats.npz

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader, ConcatDataset, Subset
import numpy as np
import os, sys
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler

# Ajouter le dossier racine au path pour accéder à src/
sys.path.append(os.path.abspath(".."))
from src.models.eegnet import EEGNetLight

def train_multirun():
    subject = 1
    runs = [6, 10, 14]
    data_dir = "../../data/processed"

    # Charger et concaténer les données de plusieurs runs
    datasets = []
    for run in runs:
        path = os.path.join(data_dir, f"subject_{subject}_run_{run}_epochs.npz")
        data = np.load(path)
        X = data["X"]
        y = data["y"]
        y = np.where(y == 2, 1, y)  # Fusion des classes 1 et 2
        y = y - y.min()
        X_tensor = torch.tensor(X, dtype=torch.float32).unsqueeze(1)
        y_tensor = torch.tensor(y, dtype=torch.long)
        datasets.append(TensorDataset(X_tensor, y_tensor))

    full_X = torch.cat([d.tensors[0] for d in datasets])
    full_y = torch.cat([d.tensors[1] for d in datasets])

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    fold = 1
    for train_idx, test_idx in skf.split(full_X, full_y):
        print(f"\n===== Fold {fold} =====")
        X_train, y_train = full_X[train_idx], full_y[train_idx]
        X_test, y_test = full_X[test_idx], full_y[test_idx]

        print(f"🔢 Répartition y_train : {torch.bincount(y_train)}")
        print(f"🔢 Répartition y_test  : {torch.bincount(y_test)}")

        # Sur-échantillonnage sur les données d'entraînement
        ros = RandomOverSampler()
        X_train_np = X_train.numpy().reshape(len(X_train), -1)
        X_resampled, y_resampled = ros.fit_resample(X_train_np, y_train.numpy())
        X_resampled = torch.tensor(X_resampled.reshape(-1, 1, X_train.shape[2], X_train.shape[3]), dtype=torch.float32)
        y_resampled = torch.tensor(y_resampled, dtype=torch.long)

        train_loader = DataLoader(TensorDataset(X_resampled, y_resampled), batch_size=8, shuffle=True)
        test_loader = DataLoader(TensorDataset(X_test, y_test), batch_size=8)

        n_channels, n_timepoints = full_X.shape[2], full_X.shape[3]
        n_classes = len(torch.unique(full_y))
        model = EEGNetLight(n_channels=n_channels, n_timepoints=n_timepoints, n_classes=n_classes)
        optimizer = optim.Adam(model.parameters(), lr=1e-3)

        # Calcul des poids de classes pour la loss
        class_counts = torch.bincount(y_resampled)
        class_weights = 1.0 / class_counts.float()
        class_weights = class_weights / class_weights.sum() * len(class_counts)
        criterion = nn.CrossEntropyLoss(weight=class_weights)

        losses, accuracies = [], []

        for epoch in range(10):
            model.train()
            total_loss, correct, total = 0, 0, 0
            for xb, yb in train_loader:
                optimizer.zero_grad()
                preds = model(xb)
                loss = criterion(preds, yb)
                loss.backward()
                optimizer.step()
                total_loss += loss.item()
                correct += (preds.argmax(1) == yb).sum().item()
                total += yb.size(0)
            acc = 100 * correct / total
            losses.append(total_loss)
            accuracies.append(acc)
            print(f"🧠 Fold {fold} — Epoch {epoch+1:02d} — Loss: {total_loss:.4f} — Acc: {acc:.2f}%")

        # Évaluation
        model.eval()
        y_true, y_pred = [], []
        with torch.no_grad():
            for xb, yb in test_loader:
                preds = model(xb)
                y_true.extend(yb.numpy())
                y_pred.extend(preds.argmax(1).numpy())

        cm = confusion_matrix(y_true, y_pred)
        ConfusionMatrixDisplay(cm).plot()
        plt.title(f"Matrice de confusion - Fold {fold}")
        plt.grid(False)
        plt.show()

        print("\n🔎 Rapport de classification :")
        print(classification_report(y_true, y_pred, zero_division=0))

        # Export stats
        np.savez(f"../../models/eegnet_subject{subject}_fold{fold}_stats.npz",
                 losses=np.array(losses), accuracies=np.array(accuracies))
        print(f"📦 Courbes sauvegardées dans eegnet_subject{subject}_fold{fold}_stats.npz")

        fold += 1

if __name__ == "__main__":
    train_multirun()
# Out:
# ===== Fold 1 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 1 — Epoch 01 — Loss: 6.2184 — Acc: 55.56%
# 🧠 Fold 1 — Epoch 02 — Loss: 6.0723 — Acc: 81.94%
# 🧠 Fold 1 — Epoch 03 — Loss: 5.6930 — Acc: 88.89%
# 🧠 Fold 1 — Epoch 04 — Loss: 4.9271 — Acc: 86.11%
# 🧠 Fold 1 — Epoch 05 — Loss: 3.8246 — Acc: 88.89%
# 🧠 Fold 1 — Epoch 06 — Loss: 2.8856 — Acc: 88.89%
# 🧠 Fold 1 — Epoch 07 — Loss: 2.1191 — Acc: 93.06%
# 🧠 Fold 1 — Epoch 08 — Loss: 1.5629 — Acc: 94.44%
# 🧠 Fold 1 — Epoch 09 — Loss: 1.1983 — Acc: 94.44%
# 🧠 Fold 1 — Epoch 10 — Loss: 0.9379 — Acc: 98.61%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.75      0.33      0.46         9
#            1       0.57      0.89      0.70         9
#
#     accuracy                           0.61        18
#    macro avg       0.66      0.61      0.58        18
# weighted avg       0.66      0.61      0.58        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold1_stats.npz
#
# ===== Fold 2 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 2 — Epoch 01 — Loss: 6.2343 — Acc: 54.17%
# 🧠 Fold 2 — Epoch 02 — Loss: 6.1343 — Acc: 83.33%
# 🧠 Fold 2 — Epoch 03 — Loss: 5.8564 — Acc: 81.94%
# 🧠 Fold 2 — Epoch 04 — Loss: 5.3138 — Acc: 81.94%
# 🧠 Fold 2 — Epoch 05 — Loss: 4.3571 — Acc: 80.56%
# 🧠 Fold 2 — Epoch 06 — Loss: 3.5600 — Acc: 84.72%
# 🧠 Fold 2 — Epoch 07 — Loss: 3.1118 — Acc: 88.89%
# 🧠 Fold 2 — Epoch 08 — Loss: 2.6075 — Acc: 88.89%
# 🧠 Fold 2 — Epoch 09 — Loss: 2.2636 — Acc: 95.83%
# 🧠 Fold 2 — Epoch 10 — Loss: 1.8658 — Acc: 97.22%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         9
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold2_stats.npz
#
# ===== Fold 3 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 3 — Epoch 01 — Loss: 6.1986 — Acc: 54.17%
# 🧠 Fold 3 — Epoch 02 — Loss: 5.9534 — Acc: 80.56%
# 🧠 Fold 3 — Epoch 03 — Loss: 5.3919 — Acc: 77.78%
# 🧠 Fold 3 — Epoch 04 — Loss: 4.7397 — Acc: 81.94%
# 🧠 Fold 3 — Epoch 05 — Loss: 4.0227 — Acc: 83.33%
# 🧠 Fold 3 — Epoch 06 — Loss: 3.5650 — Acc: 80.56%
# 🧠 Fold 3 — Epoch 07 — Loss: 3.2845 — Acc: 83.33%
# 🧠 Fold 3 — Epoch 08 — Loss: 2.7696 — Acc: 88.89%
# 🧠 Fold 3 — Epoch 09 — Loss: 2.4901 — Acc: 93.06%
# 🧠 Fold 3 — Epoch 10 — Loss: 2.1351 — Acc: 94.44%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         9
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold3_stats.npz
#
# ===== Fold 4 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 4 — Epoch 01 — Loss: 6.2253 — Acc: 55.56%
# 🧠 Fold 4 — Epoch 02 — Loss: 6.0890 — Acc: 77.78%
# 🧠 Fold 4 — Epoch 03 — Loss: 5.7227 — Acc: 83.33%
# 🧠 Fold 4 — Epoch 04 — Loss: 4.9000 — Acc: 86.11%
# 🧠 Fold 4 — Epoch 05 — Loss: 4.0270 — Acc: 80.56%
# 🧠 Fold 4 — Epoch 06 — Loss: 3.3066 — Acc: 81.94%
# 🧠 Fold 4 — Epoch 07 — Loss: 2.7219 — Acc: 87.50%
# 🧠 Fold 4 — Epoch 08 — Loss: 2.4253 — Acc: 93.06%
# 🧠 Fold 4 — Epoch 09 — Loss: 1.9455 — Acc: 95.83%
# 🧠 Fold 4 — Epoch 10 — Loss: 1.6784 — Acc: 95.83%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         9
#            1       0.50      1.00      0.67         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold4_stats.npz
#
# ===== Fold 5 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 5 — Epoch 01 — Loss: 6.2214 — Acc: 59.72%
# 🧠 Fold 5 — Epoch 02 — Loss: 6.0649 — Acc: 90.28%
# 🧠 Fold 5 — Epoch 03 — Loss: 5.6627 — Acc: 86.11%
# 🧠 Fold 5 — Epoch 04 — Loss: 4.9451 — Acc: 86.11%
# 🧠 Fold 5 — Epoch 05 — Loss: 3.9182 — Acc: 86.11%
# 🧠 Fold 5 — Epoch 06 — Loss: 3.3040 — Acc: 86.11%
# 🧠 Fold 5 — Epoch 07 — Loss: 2.8550 — Acc: 86.11%
# 🧠 Fold 5 — Epoch 08 — Loss: 2.4825 — Acc: 88.89%
# 🧠 Fold 5 — Epoch 09 — Loss: 2.2263 — Acc: 91.67%
# 🧠 Fold 5 — Epoch 10 — Loss: 2.0268 — Acc: 93.06%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         9
#            1       0.50      1.00      0.67         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold5_stats.npz

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader, ConcatDataset, Subset
import numpy as np
import os, sys
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import RandomOverSampler

# Ajouter le dossier racine au path pour accéder à src/
sys.path.append(os.path.abspath(".."))
from src.models.eegnet import EEGNetLight

def train_multirun():
    subject = 1
    runs = [6, 10, 14]
    data_dir = "../../data/processed"

    # Charger et concaténer les données de plusieurs runs
    datasets = []
    for run in runs:
        path = os.path.join(data_dir, f"subject_{subject}_run_{run}_epochs.npz")
        data = np.load(path)
        X = data["X"]
        y = data["y"]
        # 🧠 Fusion des classes 1 et 2
        y = np.where(y == 2, 1, y)
        y = y - y.min()
        X_tensor = torch.tensor(X, dtype=torch.float32).unsqueeze(1)
        y_tensor = torch.tensor(y, dtype=torch.long)
        datasets.append(TensorDataset(X_tensor, y_tensor))

    full_X = torch.cat([d.tensors[0] for d in datasets])
    full_y = torch.cat([d.tensors[1] for d in datasets])

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    fold = 1
    for train_idx, test_idx in skf.split(full_X, full_y):
        print(f"\n===== Fold {fold} =====")
        y_train, y_test = full_y[train_idx], full_y[test_idx]
        print(f"🔢 Répartition y_train : {torch.bincount(y_train)}")
        print(f"🔢 Répartition y_test  : {torch.bincount(y_test)}")

        # Appliquer l’oversampling sur les données d'entraînement uniquement
        ros = RandomOverSampler(random_state=42)
        X_train_np, y_train_np = full_X[train_idx].numpy(), full_y[train_idx].numpy()
        X_train_res, y_train_res = ros.fit_resample(X_train_np.reshape(len(X_train_np), -1), y_train_np)
        X_train_res = torch.tensor(X_train_res.reshape(-1, 1, full_X.shape[2], full_X.shape[3]), dtype=torch.float32)
        y_train_res = torch.tensor(y_train_res, dtype=torch.long)

        train_loader = DataLoader(TensorDataset(X_train_res, y_train_res), batch_size=8, shuffle=True)
        test_loader = DataLoader(Subset(TensorDataset(full_X, full_y), test_idx), batch_size=8)

        n_channels, n_timepoints = full_X.shape[2], full_X.shape[3]
        n_classes = len(torch.unique(full_y))
        model = EEGNetLight(n_channels=n_channels, n_timepoints=n_timepoints, n_classes=n_classes)
        optimizer = optim.Adam(model.parameters(), lr=1e-3)
        criterion = nn.CrossEntropyLoss()

        losses, accuracies = [], []

        for epoch in range(10):
            model.train()
            total_loss, correct, total = 0, 0, 0
            for xb, yb in train_loader:
                optimizer.zero_grad()
                preds = model(xb)
                loss = criterion(preds, yb)
                loss.backward()
                optimizer.step()
                total_loss += loss.item()
                correct += (preds.argmax(1) == yb).sum().item()
                total += yb.size(0)
            acc = 100 * correct / total
            losses.append(total_loss)
            accuracies.append(acc)
            print(f"🧠 Fold {fold} — Epoch {epoch+1:02d} — Loss: {total_loss:.4f} — Acc: {acc:.2f}%")

        # Évaluation
        model.eval()
        y_true, y_pred = [], []
        with torch.no_grad():
            for xb, yb in test_loader:
                preds = model(xb)
                y_true.extend(yb.numpy())
                y_pred.extend(preds.argmax(1).numpy())

        # Matrice de confusion et rapport
        cm = confusion_matrix(y_true, y_pred)
        ConfusionMatrixDisplay(cm).plot()
        plt.title(f"Matrice de confusion - Fold {fold}")
        plt.grid(False)
        plt.show()

        print("\n🔎 Rapport de classification :")
        print(classification_report(y_true, y_pred, zero_division=0))

        # Exporter stats
        np.savez(f"../../models/eegnet_subject{subject}_fold{fold}_stats.npz",
                 losses=np.array(losses), accuracies=np.array(accuracies))
        print(f"📦 Courbes sauvegardées dans eegnet_subject{subject}_fold{fold}_stats.npz")

        fold += 1

if __name__ == "__main__":
    train_multirun()
# Out:
# ===== Fold 1 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 1 — Epoch 01 — Loss: 6.2153 — Acc: 63.89%
# 🧠 Fold 1 — Epoch 02 — Loss: 6.0631 — Acc: 77.78%
# 🧠 Fold 1 — Epoch 03 — Loss: 5.6935 — Acc: 79.17%
# 🧠 Fold 1 — Epoch 04 — Loss: 4.9227 — Acc: 81.94%
# 🧠 Fold 1 — Epoch 05 — Loss: 3.9484 — Acc: 83.33%
# 🧠 Fold 1 — Epoch 06 — Loss: 2.9821 — Acc: 84.72%
# 🧠 Fold 1 — Epoch 07 — Loss: 2.3164 — Acc: 90.28%
# 🧠 Fold 1 — Epoch 08 — Loss: 1.7958 — Acc: 91.67%
# 🧠 Fold 1 — Epoch 09 — Loss: 1.3592 — Acc: 95.83%
# 🧠 Fold 1 — Epoch 10 — Loss: 0.9993 — Acc: 95.83%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         9
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold1_stats.npz
#
# ===== Fold 2 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 2 — Epoch 01 — Loss: 6.2236 — Acc: 50.00%
# 🧠 Fold 2 — Epoch 02 — Loss: 6.0547 — Acc: 83.33%
# 🧠 Fold 2 — Epoch 03 — Loss: 5.7124 — Acc: 81.94%
# 🧠 Fold 2 — Epoch 04 — Loss: 5.0811 — Acc: 81.94%
# 🧠 Fold 2 — Epoch 05 — Loss: 4.1954 — Acc: 81.94%
# 🧠 Fold 2 — Epoch 06 — Loss: 3.4849 — Acc: 84.72%
# 🧠 Fold 2 — Epoch 07 — Loss: 2.9728 — Acc: 88.89%
# 🧠 Fold 2 — Epoch 08 — Loss: 2.5702 — Acc: 90.28%
# 🧠 Fold 2 — Epoch 09 — Loss: 2.0240 — Acc: 93.06%
# 🧠 Fold 2 — Epoch 10 — Loss: 1.8949 — Acc: 94.44%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         9
#            1       0.50      1.00      0.67         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold2_stats.npz
#
# ===== Fold 3 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 3 — Epoch 01 — Loss: 6.2108 — Acc: 58.33%
# 🧠 Fold 3 — Epoch 02 — Loss: 6.0193 — Acc: 81.94%
# 🧠 Fold 3 — Epoch 03 — Loss: 5.5220 — Acc: 80.56%
# 🧠 Fold 3 — Epoch 04 — Loss: 4.9879 — Acc: 81.94%
# 🧠 Fold 3 — Epoch 05 — Loss: 4.1625 — Acc: 81.94%
# 🧠 Fold 3 — Epoch 06 — Loss: 3.6602 — Acc: 79.17%
# 🧠 Fold 3 — Epoch 07 — Loss: 3.2255 — Acc: 83.33%
# 🧠 Fold 3 — Epoch 08 — Loss: 2.7744 — Acc: 87.50%
# 🧠 Fold 3 — Epoch 09 — Loss: 2.3793 — Acc: 94.44%
# 🧠 Fold 3 — Epoch 10 — Loss: 2.0256 — Acc: 95.83%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         9
#            1       0.00      0.00      0.00         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold3_stats.npz
#
# ===== Fold 4 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 4 — Epoch 01 — Loss: 6.2202 — Acc: 69.44%
# 🧠 Fold 4 — Epoch 02 — Loss: 5.9932 — Acc: 81.94%
# 🧠 Fold 4 — Epoch 03 — Loss: 5.5461 — Acc: 84.72%
# 🧠 Fold 4 — Epoch 04 — Loss: 4.7203 — Acc: 84.72%
# 🧠 Fold 4 — Epoch 05 — Loss: 3.8416 — Acc: 83.33%
# 🧠 Fold 4 — Epoch 06 — Loss: 3.1522 — Acc: 84.72%
# 🧠 Fold 4 — Epoch 07 — Loss: 2.6894 — Acc: 90.28%
# 🧠 Fold 4 — Epoch 08 — Loss: 2.2045 — Acc: 93.06%
# 🧠 Fold 4 — Epoch 09 — Loss: 1.7237 — Acc: 97.22%
# 🧠 Fold 4 — Epoch 10 — Loss: 1.2964 — Acc: 97.22%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.50      0.89      0.64         9
#            1       0.50      0.11      0.18         9
#
#     accuracy                           0.50        18
#    macro avg       0.50      0.50      0.41        18
# weighted avg       0.50      0.50      0.41        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold4_stats.npz
#
# ===== Fold 5 =====
# 🔢 Répartition y_train : tensor([36, 36])
# 🔢 Répartition y_test  : tensor([9, 9])
# 🧠 Fold 5 — Epoch 01 — Loss: 6.2198 — Acc: 58.33%
# 🧠 Fold 5 — Epoch 02 — Loss: 6.0248 — Acc: 86.11%
# 🧠 Fold 5 — Epoch 03 — Loss: 5.6273 — Acc: 84.72%
# 🧠 Fold 5 — Epoch 04 — Loss: 4.8235 — Acc: 83.33%
# 🧠 Fold 5 — Epoch 05 — Loss: 4.0606 — Acc: 84.72%
# 🧠 Fold 5 — Epoch 06 — Loss: 3.4549 — Acc: 84.72%
# 🧠 Fold 5 — Epoch 07 — Loss: 3.0883 — Acc: 87.50%
# 🧠 Fold 5 — Epoch 08 — Loss: 2.6117 — Acc: 90.28%
# 🧠 Fold 5 — Epoch 09 — Loss: 2.2749 — Acc: 90.28%
# 🧠 Fold 5 — Epoch 10 — Loss: 2.0864 — Acc: 91.67%
# 🔎 Rapport de classification :
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         9
#            1       0.50      1.00      0.67         9
#
#     accuracy                           0.50        18
#    macro avg       0.25      0.50      0.33        18
# weighted avg       0.25      0.50      0.33        18
#
# 📦 Courbes sauvegardées dans eegnet_subject1_fold5_stats.npz

# %%
import mne
import os
from src.preprocessing.windowing import extract_epochs_from_annotations

subject = 1
runs = [6, 10, 14]
output_dir = "../../data/processed"
os.makedirs(output_dir, exist_ok=True)

for run in runs:
    files = mne.datasets.eegbci.load_data(subject=subject, runs=[run])
    raw = mne.io.read_raw_edf(files[0], preload=True)
    raw.rename_channels(lambda name: name.strip(".").upper())
    raw.set_montage("standard_1020", on_missing="ignore")

    X, y = extract_epochs_from_annotations(
        raw, tmin=0.0, tmax=4.0,
        output_path=os.path.join(output_dir, f"subject_{subject}_run_{run}_epochs.npz")
    )
    print(f"✅ Run {run} exporté : {X.shape} échantillons")
