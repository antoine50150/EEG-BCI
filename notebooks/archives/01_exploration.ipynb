# %%
import mne

# Runs de mouvement main gauche, droite, et les deux
runs = [6, 10, 14]
subject = 1
files = mne.datasets.eegbci.load_data(subjects=[subject], runs=runs)

raw = mne.io.read_raw_edf(files[0], preload=True)
raw.rename_channels(lambda name: name.strip(".").upper())
raw.set_montage("standard_1020", on_missing="ignore")

# Affichage
print(raw.ch_names)
# Out:
# Extracting EDF parameters from C:\Users\Antoi\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S001\S001R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# ['FC5', 'FC3', 'FC1', 'FCZ', 'FC2', 'FC4', 'FC6', 'C5', 'C3', 'C1', 'CZ', 'C2', 'C4', 'C6', 'CP5', 'CP3', 'CP1', 'CPZ', 'CP2', 'CP4', 'CP6', 'FP1', 'FPZ', 'FP2', 'AF7', 'AF3', 'AFZ', 'AF4', 'AF8', 'F7', 'F5', 'F3', 'F1', 'FZ', 'F2', 'F4', 'F6', 'F8', 'FT7', 'FT8', 'T7', 'T8', 'T9', 'T10', 'TP7', 'TP8', 'P7', 'P5', 'P3', 'P1', 'PZ', 'P2', 'P4', 'P6', 'P8', 'PO7', 'PO3', 'POZ', 'PO4', 'PO8', 'O1', 'OZ', 'O2', 'IZ']

# %%
# Affichage d’un extrait du signal EEG (10 premières secondes)
raw.plot(start=0, duration=10, scalings='auto')
# Out:
# Using qt as 2D backend.

# %%
# Tracer la PSD des canaux moteurs
channels_motor = ["C3", "C4", "CZ", "FCZ", "CPZ"]
raw.compute_psd(picks=channels_motor, fmin=1, fmax=40).plot()
# Out:
# Effective window size : 12.800 (s)
# Plotting power spectral density (dB=True).
# C:\Users\Antoi\miniconda3\envs\eeg-bci-env\lib\site-packages\mne\viz\utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 2 Axes>
# <MNELineFigure size 1000x350 with 2 Axes>

# %%
# Affichage topographique (nécessite le montage)
psd = raw.compute_psd(fmin=1, fmax=40)
psd.plot_topomap(ch_type='eeg', normalize=True)
# Out:
# Effective window size : 12.800 (s)
# -----------------------------------------------------------------------
# ValueError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Affichage topographique (nécessite le montage)
#       2 psd = raw.compute_psd(fmin=1, fmax=40)
# ----> 3 psd.plot_topomap(ch_type='eeg', normalize=True)
#
# File ~\miniconda3\envs\eeg-bci-env\lib\site-packages\mne\time_frequency\spectrum.py:849, in BaseSpectrum.plot_topomap(self, bands, ch_type, normalize, agg_fun, dB, sensors, show_names, mask, mask_params, contours, outlines, sphere, image_interp, extrapolate, border, res, size, cmap, vlim, cnorm, colorbar, cbar_fmt, units, axes, show)
#     838 scalings = _handle_default("scalings", None)
#     839 scaling = scalings[ch_type]
#     841 (
#     842     picks,
#     843     pos,
#     844     merge_channels,
#     845     names,
#     846     ch_type,
#     847     sphere,
#     848     clip_origin,
# --> 849 ) = _prepare_topomap_plot(self, ch_type, sphere=sphere)
#     850 outlines = _make_head_outlines(sphere, pos, outlines, clip_origin)
#     852 psds, freqs = self.get_data(picks=picks, return_freqs=True)
#
# File ~\miniconda3\envs\eeg-bci-env\lib\site-packages\mne\viz\topomap.py:127, in _prepare_topomap_plot(inst, ch_type, sphere)
#     124 info._check_consistency()
#     126 # special case for merging grad channels
# --> 127 layout = find_layout(info)
#     128 if (
#     129     ch_type == "grad"
#     130     and layout is not None
#    (...)
#     134     )
#     135 ):
#     136     picks, _ = _pair_grad_sensors(info, layout)
#
# File ~\miniconda3\envs\eeg-bci-env\lib\site-packages\mne\channels\layout.py:627, in find_layout(info, ch_type, exclude)
#     622     if not isinstance(info, dict | Info):
#     623         raise RuntimeError(
#     624             "Cannot make EEG layout, no measurement info "
#     625             "was passed to `find_layout`"
#     626         )
# --> 627     return make_eeg_layout(info, exclude=exclude)
#     628 elif has_csd_coils and ch_type in [None, "csd"]:
#     629     return make_eeg_layout(info, exclude=exclude, csd=True)
#
# File ~\miniconda3\envs\eeg-bci-env\lib\site-packages\mne\channels\layout.py:447, in make_eeg_layout(info, radius, width, height, exclude, csd)
#     445     pick_kwargs.update(csd=True, eeg=False)
#     446 picks = pick_types(info, **pick_kwargs)
# --> 447 loc2d = _find_topomap_coords(info, picks)
#     448 names = [info["chs"][i]["ch_name"] for i in picks]
#     450 # Scale [x, y] to be in the range [-0.5, 0.5]
#     451 # Don't mess with the origin or aspect ratio
#
# File ~\miniconda3\envs\eeg-bci-env\lib\site-packages\mne\channels\layout.py:858, in _find_topomap_coords(info, picks, layout, ignore_overlap, to_sphere, sphere)
#     856     pos = np.asarray(pos)
#     857 else:
# --> 858     pos = _auto_topomap_coords(
#     859         info,
#     860         picks,
#     861         ignore_overlap=ignore_overlap,
#     862         to_sphere=to_sphere,
#     863         sphere=sphere,
#     864     )
#     866 return pos
#
# File ~\miniconda3\envs\eeg-bci-env\lib\site-packages\mne\channels\layout.py:972, in _auto_topomap_coords(info, picks, ignore_overlap, to_sphere, sphere)
#     966 if len(locs3d) > 1 and np.min(dist) < 1e-10 and not ignore_overlap:
#     967     problematic_electrodes = [
#     968         chs[elec_i]["ch_name"]
#     969         for elec_i in squareform(dist < 1e-10).any(axis=0).nonzero()[0]
#     970     ]
# --> 972     raise ValueError(
#     973         "The following electrodes have overlapping positions,"
#     974         " which causes problems during visualization:\n"
#     975         + ", ".join(problematic_electrodes)
#     976     )
#     978 if to_sphere:
#     979     # translate to sphere origin, transform/flatten Z, translate back
#     980     locs3d -= sphere[:3]
#
# ValueError: The following electrodes have overlapping positions, which causes problems during visualization:
# FCZ, CZ, CPZ, FP1, FPZ, FP2, AFZ, FZ, PZ, POZ, OZ, IZ

# %%
# Détection automatique des positions qui se chevauchent
from mne.channels import make_standard_montage

# Appliquer le montage standard (avec positions valides)
montage = make_standard_montage("standard_1005")
raw.set_montage(montage, on_missing="ignore")

# Corriger les conflits en supprimant les canaux problématiques
raw.drop_channels(["CZ", "FCZ", "CPZ"])

# Affichage PSD sur les autres électrodes moteur (ex : C3, C4, CP1, CP2)
channels_motor = ["C3", "C4", "CP1", "CP2"]
psd = raw.compute_psd(picks=channels_motor, fmin=1, fmax=40)
psd.plot()

# ✅ Topomap sans canaux conflictuels
psd.plot_topomap(ch_type="eeg", normalize=True)
# Out:
# Effective window size : 12.800 (s)
# Plotting power spectral density (dB=True).
# C:\Users\Antoi\miniconda3\envs\eeg-bci-env\lib\site-packages\mne\viz\utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 2 Axes>
# Channels marked as bad:
# none
